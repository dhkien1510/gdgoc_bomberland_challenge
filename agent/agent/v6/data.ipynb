# %%
%
# %python agent/agent/v6/collect_dataset.py --num_episodes 200 --scenario survive --output_dir agent/agent/v6/bc_data_smoke_v2/survive
# %python agent/agent/v6/collect_dataset.py --num_episodes 200 --scenario pressure --output_dir agent/agent/v6/bc_data_smoke_v2/pressure
# %python agent/agent/v6/collect_dataset.py --num_episodes 200 --scenario selfplay --output_dir agent/agent/v6/bc_data_smoke_v2/selfplay
# Out:
# Running cells with 'aic_gdgoc (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/other/CNTT/Bomberland-GDGoC-AI-Challenge/aic_gdgoc/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
